# %% [markdown]
# # Классификация пород кошек и собак по лицу

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import seaborn as sn
import pandas as pd

from tensorflow.keras import utils
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import SparseTopKCategoricalAccuracy

from pathlib import Path

# %% [markdown]
# Используем упрощенный датасет [Oxford-IIIT Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/) с вырезанными лицами домашних животных. Для начала загружаем датасет:

# %%
url = 'http://www.soshnikov.com/permanent/data/petfaces.tar.gz'
dataset = Path(utils.get_file('petfaces', origin=url, untar=True))

img_size = 256, 256

# %% [markdown]
# ## Обработка входных данных
#
# ### Разделение на обучающую и тестовую выборки

# %%
SEED = 2904

train = utils.image_dataset_from_directory(
    dataset, 
    validation_split=0.2, 
    subset='training', 
    seed=SEED,
    image_size=img_size,
    batch_size=32)

test = utils.image_dataset_from_directory(
    dataset, 
    validation_split=0.2, 
    subset='validation', 
    seed=SEED,
    image_size=img_size,
    batch_size=32)

class_names = train.class_names
# Out:
# Found 3211 files belonging to 35 classes.
# Using 2569 files for training.
# Found 3211 files belonging to 35 classes.
# Using 642 files for validation.

# %% [markdown]
# ### Предобработка входных данных

# %%
cats, dogs = list(), list()

for i in range(len(class_names)):
    if class_names[i].startswith('cat'):
        cats.append(i)
    if class_names[i].startswith('dog'):
        dogs.append(i)

train = train.cache().shuffle(SEED//2).prefetch(buffer_size=tf.data.AUTOTUNE)
test = test.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Обучение модели

# %%
model = Sequential()

model.add(layers.RandomFlip("horizontal", input_shape=(img_size[0], img_size[1], 3)),)
model.add(layers.RandomRotation(0.1),)
model.add(layers.RandomZoom(0.1),)
model.add(layers.Conv2D(16, 3, activation='relu'))
model.add(layers.MaxPooling2D(2))
model.add(layers.Conv2D(32, 3, activation='relu'))
model.add(layers.MaxPooling2D(2))
model.add(layers.Conv2D(64, 3, activation='relu'))
model.add(layers.MaxPooling2D(2))
model.add(layers.Flatten())
model.add(layers.Dropout(0.2))
model.add(layers.Dense(len(class_names)))
model.add(layers.Softmax())

# %%
top3_accuracy = SparseTopKCategoricalAccuracy(k=3, name='top3_accuracy')

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy', top3_accuracy])

# %%
# tf.config.list_physical_devices('GPU')
epochs = 32

history = model.fit(train, validation_data=test, epochs=epochs)
# Out:
# Epoch 1/32
# 81/81 [==============================] - 55s 649ms/step - loss: 19.4968 - accuracy: 0.0572 - top3_accuracy: 0.1534 - val_loss: 3.3033 - val_accuracy: 0.1231 - val_top3_accuracy: 0.2570
# Epoch 2/32
# 81/81 [==============================] - 53s 648ms/step - loss: 3.2507 - accuracy: 0.1316 - top3_accuracy: 0.2795 - val_loss: 3.0064 - val_accuracy: 0.2134 - val_top3_accuracy: 0.3956
# Epoch 3/32
# 81/81 [==============================] - 52s 644ms/step - loss: 3.0751 - accuracy: 0.1678 - top3_accuracy: 0.3643 - val_loss: 2.8834 - val_accuracy: 0.2259 - val_top3_accuracy: 0.4502
# 81/81 [==============================] - 49s 601ms/step - loss: 2.3959 - accuracy: 0.3511 - top3_accuracy: 0.5808 - val_loss: 2.5246 - val_accuracy: 0.3333 - val_top3_accuracy: 0.5794
# Epoch 17/32
# 81/81 [==============================] - 48s 599ms/step - loss: 2.2330 - accuracy: 0.3756 - top3_accuracy: 0.6216 - val_loss: 2.4677 - val_accuracy: 0.3489 - val_top3_accuracy: 0.5763
# Epoch 18/32
# 81/81 [==============================] - 49s 601ms/step - loss: 2.2030 - accuracy: 0.4052 - top3_accuracy: 0.6442 - val_loss: 2.3948 - val_accuracy: 0.3598 - val_top3_accuracy: 0.6277
# Epoch 19/32
# 81/81 [==============================] - 51s 629ms/step - loss: 2.0960 - accuracy: 0.4099 - top3_accuracy: 0.6625 - val_loss: 2.5552 - val_accuracy: 0.3146 - val_top3_accuracy: 0.5545
# Epoch 20/32
# 81/81 [==============================] - 51s 630ms/step - loss: 2.0811 - accuracy: 0.4325 - top3_accuracy: 0.6633 - val_loss: 2.2924 - val_accuracy: 0.3894 - val_top3_accuracy: 0.6573
# Epoch 21/32
# 81/81 [==============================] - 51s 624ms/step - loss: 1.9662 - accuracy: 0.4613 - top3_accuracy: 0.6921 - val_loss: 2.1917 - val_accuracy: 0.4112 - val_top3_accuracy: 0.6776
# Epoch 22/32
# 81/81 [==============================] - 51s 624ms/step - loss: 2.0231 - accuracy: 0.4527 - top3_accuracy: 0.6882 - val_loss: 2.4433 - val_accuracy: 0.3411 - val_top3_accuracy: 0.5935
# Epoch 23/32
# 81/81 [==============================] - 48s 599ms/step - loss: 1.9334 - accuracy: 0.4675 - top3_accuracy: 0.7007 - val_loss: 2.2357 - val_accuracy: 0.4330 - val_top3_accuracy: 0.6620
# Epoch 24/32
# 81/81 [==============================] - 49s 601ms/step - loss: 1.8148 - accuracy: 0.4811 - top3_accuracy: 0.7275 - val_loss: 2.1673 - val_accuracy: 0.4159 - val_top3_accuracy: 0.6838
# Epoch 25/32
# 81/81 [==============================] - 49s 602ms/step - loss: 1.7646 - accuracy: 0.5091 - top3_accuracy: 0.7376 - val_loss: 2.1046 - val_accuracy: 0.4283 - val_top3_accuracy: 0.6963
# Epoch 26/32
# 81/81 [==============================] - 49s 600ms/step - loss: 1.7060 - accuracy: 0.5185 - top3_accuracy: 0.7559 - val_loss: 2.1341 - val_accuracy: 0.4361 - val_top3_accuracy: 0.6822
# Epoch 27/32
# 81/81 [==============================] - 49s 602ms/step - loss: 1.6570 - accuracy: 0.5302 - top3_accuracy: 0.7555 - val_loss: 2.1208 - val_accuracy: 0.4517 - val_top3_accuracy: 0.6963
# Epoch 28/32
# 81/81 [==============================] - 49s 604ms/step - loss: 1.5737 - accuracy: 0.5590 - top3_accuracy: 0.7766 - val_loss: 2.0763 - val_accuracy: 0.4626 - val_top3_accuracy: 0.7072
# Epoch 29/32
# 81/81 [==============================] - 49s 606ms/step - loss: 1.5339 - accuracy: 0.5566 - top3_accuracy: 0.7882 - val_loss: 2.1004 - val_accuracy: 0.4486 - val_top3_accuracy: 0.7196
# Epoch 30/32
# 81/81 [==============================] - 49s 605ms/step - loss: 1.4986 - accuracy: 0.5699 - top3_accuracy: 0.7984 - val_loss: 2.0391 - val_accuracy: 0.4673 - val_top3_accuracy: 0.7336
# Epoch 31/32
# 81/81 [==============================] - 49s 607ms/step - loss: 1.4271 - accuracy: 0.5928 - top3_accuracy: 0.8089 - val_loss: 1.9663 - val_accuracy: 0.4860 - val_top3_accuracy: 0.7383
# Epoch 32/32
# 81/81 [==============================] - 51s 624ms/step - loss: 1.4059 - accuracy: 0.5924 - top3_accuracy: 0.8163 - val_loss: 1.9900 - val_accuracy: 0.4953 - val_top3_accuracy: 0.7461

# %% [markdown]
# ## Точность классификатора

# %% [markdown]
# ### Метрики

# %% [markdown]
# #### Accuracy

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(15, 8))
plt.subplot(1, 3, 1)
plt.plot(range(epochs), acc, label='train acc')
plt.plot(range(epochs), val_acc, label='test acc')
plt.legend()
plt.grid()
plt.title('Accuracy')

plt.show()

# %% [markdown]
# #### Loss

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(15, 8))
plt.subplot(1, 3, 1)
plt.plot(range(epochs), loss, label='train loss')
plt.plot(range(epochs), val_loss, label='test loss')
plt.legend()
plt.grid()
plt.title('Loss')

plt.show()

# %% [markdown]
# #### Top 3 accuracy

# %%
top3_acc = history.history['top3_accuracy']
val_top3_acc = history.history['val_top3_accuracy']

plt.figure(figsize=(15, 8))
plt.subplot(1, 3, 1)
plt.plot(range(epochs), top3_acc, label='train top3 acc')
plt.plot(range(epochs), val_top3_acc, label='test top3 acc')
plt.legend()
plt.grid()
plt.title('Top 3 accuracy')

plt.show()

# %% [markdown]
# ### Точность бинарной классификации

# %%
correct, total = 0, 0

for x, y in test:
    y_pred = np.argmax(model.predict(x), axis=1)
    correct_cats = sum([y_pred[i] in cats and y[i] in cats for i in range(len(y))])
    correct_dogs = sum([y_pred[i] in dogs and y[i] in dogs for i in range(len(y))])
    correct += correct_cats + correct_dogs
    total += len(y)

print('\nBinary classification accuracy: ', correct / total)
# Out:
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 86ms/step
#
# Binary classification accuracy:  0.8956386292834891

# %% [markdown]
# ### Confusion matrix

# %%
y_real = np.array([])
y_pred = np.array([])

for x, y in test:
    y_real = np.concatenate((y_real, y), axis=None)
    y_pred = np.concatenate((y_pred, np.argmax(model.predict(x), axis=1)), axis=None)    

confusion_matrix = tf.math.confusion_matrix(y_real, y_pred, num_classes=len(class_names))

df_cm = pd.DataFrame(confusion_matrix, index = [i for i in class_names], columns = [i for i in class_names])

plt.figure(figsize = (15, 15))
sn.heatmap(df_cm, annot=True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 37ms/step
