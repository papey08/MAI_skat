# %% [markdown]
# Однонаправленная LSTM

# %% [markdown]
# Импортируем необходимые зависимости

# %%
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding
from keras.preprocessing import sequence
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# Загрузим текст для обучения из txt файла

# %%
with open('texts/451.txt', 'r', encoding='windows-1251') as file:
    text = file.read()

# %% [markdown]
# Создадим токенизатор и словарь слов

# %%
tokens = word_tokenize(text)

word_dict = {}
for word in tokens:
    if word not in word_dict:
        word_dict[word] = len(word_dict) + 1

reverse_word_dict = {v: k for k, v in word_dict.items()}
print(reverse_word_dict)

sequences = [word_dict[word] for word in tokens]
# Out:
# {1: '*', 2: '451', 3: '?', 4: 'по', 5: 'Фаренгейту', 6: '[', 7: '1', 8: '-', 9: '233', 10: 'С', 11: '.', 12: '(', 13: 'Здесь', 14: 'и', 15: 'далее', 16: '–', 17: 'прим.', 18: 'перев', 19: ')', 20: ']', 21: 'температура', 22: ',', 23: 'при', 24: 'которой', 25: 'книжные', 26: 'страницы', 27: 'воспламеняются', 28: 'сгорают', 29: 'дотла…', 30: 'Эта', 31: 'книга', 32: 'с', 33: 'благодарностью', 34: 'посвящается', 35: 'Дону', 36: 'Конгдону', 37: 'Если', 38: 'тебе', 39: 'дали', 40: 'разлинованную', 41: 'бумагу', 42: 'пиши', 43: 'по-своему', 44: 'Хуан', 45: 'Рамон', 46: 'Хименес', 47: '2', 48: '1881–1958', 49: 'испанский', 50: 'поэт', 51: 'лауреат', 52: 'Нобелевской', 53: 'премии', 54: '1956', 55: 'Часть', 56: 'первая', 57: 'Домашний', 58: 'очаг', 59: 'саламандра', 60: 'Жечь', 61: 'было', 62: 'удовольствием', 63: 'А', 64: 'особым', 65: 'смотреть', 66: 'как', 67: 'огонь', 68: 'поедает', 69: 'вещи', 70: 'наблюдать', 71: 'они', 72: 'чернеют', 73: 'меняются', 74: 'В', 75: 'кулаках', 76: 'зажат', 77: 'медный', 78: 'наконечник', 79: 'гигантский', 80: 'питон', 81: 'плюется', 82: 'на', 83: 'мир', 84: 'ядовитым', 85: 'керосином', 86: 'в', 87: 'висках', 88: 'стучит', 89: 'кровь', 90: 'руки', 91: 'кажутся', 92: 'руками', 93: 'поразительного', 94: 'дирижера', 95: 'управляющего', 96: 'сразу', 97: 'всеми', 98: 'симфониями', 99: 'возжигания', 100: 'испепеления', 101: 'чтобы', 102: 'низвергнуть', 103: 'историю', 104: 'оставить', 105: 'от', 106: 'нее', 107: 'обуглившиеся', 108: 'руины', 109: 'Шлем', 110: 'символическим', 111: 'числом', 112: 'крепко', 113: 'сидит', 114: 'крутом', 115: 'лбу', 116: ';', 117: 'глазах', 118: 'оранжевым', 119: 'пламенем', 120: 'полыхает', 121: 'предвкушение', 122: 'того', 123: 'что', 124: 'сейчас', 125: 'произойдет', 126: 'он', 127: 'щелкает', 128: 'зажигателем', 129: 'весь', 130: 'дом', 131: 'прыгает', 132: 'вверх', 133: 'пожираемый', 134: 'огнем', 135: 'который', 136: 'опаляет', 137: 'вечернее', 138: 'небо', 139: 'окрашивает', 140: 'его', 141: 'красно-желто-черный', 142: 'цвет', 143: 'Он', 144: 'идет', 145: 'рое', 146: 'огненных', 147: 'светляков', 148: 'Больше', 149: 'всего', 150: 'ему', 151: 'хочется', 152: 'сделать', 153: 'то', 154: 'чем', 155: 'любил', 156: 'забавляться', 157: 'давние', 158: 'времена', 159: ':', 160: 'ткнуть', 161: 'палочку', 162: 'со', 163: 'сладким', 164: 'суфле', 165: 'маршмэллоу', 166: 'пока', 167: 'книги', 168: 'хлопая', 169: 'голубиными', 170: 'крыльями', 171: 'страниц', 172: 'гибнут', 173: 'крыльце', 174: 'газоне', 175: 'перед', 176: 'домом', 177: 'Пока', 178: 'искрящемся', 179: 'вихре', 180: 'взмывают', 181: 'ввысь', 182: 'уносятся', 183: 'прочь', 184: 'гонимые', 185: 'черным', 186: 'пепла', 187: 'ветром', 188: 'На', 189: 'лице', 190: 'Монтага', 191: 'играла', 192: 'жесткая', 193: 'ухмылка', 194: 'она', 195: 'возникает', 196: 'у', 197: 'каждого', 198: 'кто', 199: 'опаленный', 200: 'жаром', 201: 'отшатывается', 202: 'пламени', 203: 'Монтаг', 204: 'знал', 205: 'вернувшись', 206: 'пожарную', 207: 'станцию', 208: 'захочет', 209: 'взглянуть', 210: 'зеркало', 211: 'подмигнуть', 212: 'себе', 213: 'комедианту', 214: 'выкрашенным', 215: 'под', 216: 'негра', 217: 'словно', 218: 'жженой', 219: 'коркой', 220: 'лицом', 221: 'И', 222: 'затем', 223: 'темноте', 224: 'уже', 225: 'засыпая', 226: 'все', 227: 'еще', 228: 'будет', 229: 'ощущать', 230: 'огненную', 231: 'ухмылку', 232: 'скованную', 233: 'мускулами', 234: 'щек', 235: 'Сколько', 236: 'себя', 237: 'помнил', 238: 'никогда', 239: 'не', 240: 'сходила', 241: 'лица', 242: 'повесил', 243: 'свой', 244: 'черный', 245: 'жучьим', 246: 'отливом', 247: 'шлем', 248: 'протер', 249: 'до', 250: 'блеска', 251: 'аккуратно', 252: 'огнеупорную', 253: 'куртку', 254: 'наслаждением', 255: 'помылся', 256: 'душем', 257: 'после', 258: 'чего', 259: 'насвистывая', 260: 'карманах', 261: 'прошагал', 262: 'верхнему', 263: 'этажу', 264: 'пожарной', 265: 'станции', 266: 'бросился', 267: 'провал', 268: 'самую', 269: 'последнюю', 270: 'секунду', 271: 'когда', 272: 'несчастье', 273: 'каз ...

# %% [markdown]
# Создадим обучающие примеры

# %%
X = []
y = []
sequence_length = 50

for i in range(len(sequences) - sequence_length):
    X.append(sequences[i:i + sequence_length])
    y.append(sequences[i + sequence_length])

X = np.array(X)
y = to_categorical(y, num_classes=len(word_dict) + 1)

# %% [markdown]
# Создадим и обучим модель

# %%
embedding_dim = 50
hidden_units = 128

model = Sequential()
model.add(Embedding(input_dim=len(word_dict) + 1, output_dim=embedding_dim, input_length=sequence_length))
model.add(LSTM(hidden_units))
model.add(Dense(len(word_dict) + 1, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(
# 121/121 [==============================] - 14s 115ms/step - loss: 0.1367 - accuracy: 0.9872
# Epoch 82/100
# 121/121 [==============================] - 14s 117ms/step - loss: 0.1385 - accuracy: 0.9861
# Epoch 83/100
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1356 - accuracy: 0.9863
# Epoch 84/100
# 121/121 [==============================] - 14s 115ms/step - loss: 0.1276 - accuracy: 0.9886
# Epoch 85/100
# 121/121 [==============================] - 14s 115ms/step - loss: 0.1174 - accuracy: 0.9899
# Epoch 86/100
# 121/121 [==============================] - 13s 105ms/step - loss: 0.1121 - accuracy: 0.9904
# Epoch 87/100
# 121/121 [==============================] - 13s 108ms/step - loss: 0.1079 - accuracy: 0.9910
# Epoch 88/100
# 121/121 [==============================] - 14s 116ms/step - loss: 0.1057 - accuracy: 0.9908
# Epoch 89/100
# 121/121 [==============================] - 14s 118ms/step - loss: 0.1102 - accuracy: 0.9907
# Epoch 90/100
# 121/121 [==============================] - 15s 120ms/step - loss: 0.1053 - accuracy: 0.9917
# Epoch 91/100
# 121/121 [==============================] - 14s 118ms/step - loss: 0.0979 - accuracy: 0.9918
# Epoch 92/100
# 121/121 [==============================] - 15s 120ms/step - loss: 0.0952 - accuracy: 0.9927
# Epoch 93/100
# 121/121 [==============================] - 14s 115ms/step - loss: 0.1014 - accuracy: 0.9916
# Epoch 94/100
# 121/121 [==============================] - 13s 107ms/step - loss: 0.0862 - accuracy: 0.9943
# Epoch 95/100
# 121/121 [==============================] - 14s 115ms/step - loss: 0.0799 - accuracy: 0.9948
# Epoch 96/100
# 121/121 [==============================] - 15s 120ms/step - loss: 0.0776 - accuracy: 0.9952
# Epoch 97/100
# 121/121 [==============================] - 14s 113ms/step - loss: 0.0784 - accuracy: 0.9948
# Epoch 98/100
# 121/121 [==============================] - 13s 111ms/step - loss: 0.0816 - accuracy: 0.9941
# Epoch 99/100
# 121/121 [==============================] - 14s 114ms/step - loss: 0.0752 - accuracy: 0.9951
# Epoch 100/100
# 121/121 [==============================] - 13s 111ms/step - loss: 0.0689 - accuracy: 0.9961

# %% [markdown]
# Попробуем сгенерировать текст

# %%
def generate_text(seed_text):
    seed_tokens = word_tokenize(seed_text)
    seed_sequence = [word_dict[word] for word in seed_tokens]

    for _ in range(50):
        input_sequence = pad_sequences([seed_sequence], maxlen=sequence_length)
        predicted_probs = model.predict(input_sequence)[0]
        predicted_word_index = np.random.choice(np.argsort(predicted_probs)[-5:][::-1])
        seed_sequence.append(predicted_word_index)
        seed_sequence = seed_sequence[-sequence_length:]

    return seed_text + ' ' + ' '.join([reverse_word_dict[index] for index in seed_sequence])

# %%
seed_text = 'огонь'
generated_text = generate_text(seed_text)

print(generated_text)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# огонь того это совершенно стену . В нем люди за только был другой , встала вместо опять удовольствием была был тепло ни и – говорила час , что , представляете ее кивнула : она в порядке . Я стояла же , как птичка в фантастической конуре от его профессиональных дождь ;
